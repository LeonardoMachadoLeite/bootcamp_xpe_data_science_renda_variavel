# %%
import os
import sys
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())
CLASSES_DIR = os.getenv("CLASSES_DIR")
READ_DIR = os.getenv("READ_DIR")

sys.path.append(CLASSES_DIR)

#from ex_class import Ex_Class

# %%
import pandas as pd

acoes = pd.read_excel(f'{READ_DIR}\\Módulo 01\\dados_limpos_status_invest.xlsx', sheet_name='status_invest')
acoes.head()
# Out:
#   TICKER  PRECO    DY    P/L  P/VP  P/ATIVOS  MARGEM BRUTA  MARGEM EBIT
# 0  AALR3  22.70  0.00 -10.85  2.96      1.04         30.83        -1.55  \
# 1  ABCB4  17.82  6.08   4.93  0.76      0.08         32.56        26.15
# 2  ABEV3  14.58  5.23  15.58  2.70      1.70         49.71        22.46
# 3  ADHM3   1.56  0.00  -4.09 -1.29    105.12        100.00    -13548.48
# 4  AERI3   1.63  0.00 -10.75  1.45      0.38         13.11         9.22
#
#    MARG. LIQUIDA  P/EBIT  ...  PATRIMONIO / ATIVOS  PASSIVOS / ATIVOS
# 0         -22.50 -157.79  ...                 0.35               0.63  \
# 1          18.94    3.57  ...                 0.10               0.90
# 2          18.03   12.50  ...                 0.63               0.36
# 3      -18860.61   -5.69  ...               -81.72              82.72
# 4          -4.20    4.90  ...                 0.26               0.74
#
#    GIRO ATIVOS  CAGR RECEITAS 5 ANOS  CAGR LUCROS 5 ANOS
# ...

# %%
acoes.sort_values(by=['PRECO'],inplace=True)
acoes.head(10)
# Out:
#     TICKER  PRECO   DY    P/L    P/VP  P/ATIVOS  MARGEM BRUTA  MARGEM EBIT
# 546  VIVR3   0.35  0.0  -2.64    2.47      0.24         29.41       -49.76  \
# 77   BPHA3   0.62  0.0   0.06   -0.24      0.99         98.02      1029.99
# 20   AMAR3   0.65  0.0  -0.48    0.61      0.08         38.66        -8.56
# 297  INEP4   0.78  0.0  -0.39   -0.08      0.11        -75.75     -1007.89
# 440  RCSL4   0.79  0.0 -15.22  204.60      3.06         11.58         7.76
# 503  TCNO4   0.85  0.0  -5.33   -5.95      0.02          0.00         0.00
# 108  CASH3   0.86  0.0 -12.28    0.95      0.60        -41.31       -41.31
# 195  DOTZ3   0.88  0.0  -1.24   -0.63      0.32         87.88       -76.62
# 524  TRAD3   0.93  0.0  -2.28    0.52      0.46         40.71      -132.55
# 477  SLED4   0.99  0.0   0.09   -0.03      0.10         45.54       210.83
#
#      MARG. LIQUIDA  P/EBIT  ...  PATRIMONIO / ATIVOS  PASSIVOS / ATIVOS
# ...

# %%
acoes.tail(10)
# Out:
#     TICKER   PRECO     DY      P/L    P/VP  P/ATIVOS  MARGEM BRUTA
# 291  IGBR3  119.30   0.00     0.38   -0.23      0.70        100.00  \
# 128  CEPE3  125.26   0.43    81.27    5.86      0.71         19.73
# 135  CGAS5  127.80  10.25    30.82  -95.44      1.30         20.22
# 75   BPAR3  182.07   3.37     7.28    1.02      0.11         55.65
# 25   APTI3  197.64   0.00    -0.14    0.02      0.01         94.24
# 204  EEEL3  294.77  42.83     3.27    1.53      0.56         59.51
# 66   BMKS3  330.00  17.51     5.36    0.73      0.64         26.12
# 355  MOAR3  379.00   1.29    17.51    4.41      1.98          0.00
# 205  EEEL4  410.00  33.87     4.54    2.13      0.78         59.51
# 368  MSRO3  702.50   0.00  1688.87  262.32     74.39         52.18
#
#      MARGEM EBIT  MARG. LIQUIDA  P/EBIT  ...  PATRIMONIO / ATIVOS
# 291      6032.01        5379.32    0.34  ...                -3.06  \
# 128        12.27           1.41    9.36  ...                 0.12
# ...

# %%
acoes[' LIQUIDEZ MEDIA DIARIA'].describe()
# Out:
# count    5.630000e+02
# mean     3.773007e+07
# std      1.360855e+08
# min      0.000000e+00
# 25%      6.908145e+03
# 50%      2.928168e+05
# 75%      1.422970e+07
# max      1.853846e+09
# Name:  LIQUIDEZ MEDIA DIARIA, dtype: float64

# %%
list = [7, 3, 9, 2, 1, 0]
list.index(2)
# Out:
# 3

# %%
acoes.sort_values(by=[' LIQUIDEZ MEDIA DIARIA'], ascending=False,inplace=True)
acoes.head(10)
# Out:
#     TICKER  PRECO     DY    P/L  P/VP  P/ATIVOS  MARGEM BRUTA  MARGEM EBIT
# 540  VALE3  69.21   8.22   3.81  1.66      0.71         41.14        32.52  \
# 408  PETR4  25.92  64.13   1.86  0.84      0.35         52.08        45.26
# 304  ITUB4  26.87   4.71   8.66  1.54      0.11         36.93        12.47
# 45   BBDC4  16.08   6.27   8.81  1.05      0.09         33.70         9.42
# 43   BBAS3  44.04   9.80   3.92  0.77      0.06         31.57        16.70
# 37   B3SA3  13.56   2.94  18.72  3.84      1.72         87.65        53.51
# 211  ELET3  35.32   0.63  57.56  0.73      0.30         52.56        25.22
# 407  PETR3  29.29  56.75   2.10  0.95      0.39         52.08        45.26
# 425  PRIO3  36.97   0.00   9.32  3.09      1.28         65.66        58.64
# 349  MGLU3   3.64   0.00 -33.70  2.39      0.72         27.89         1.90
#
#      MARG. LIQUIDA  P/EBIT  ...  PATRIMONIO / ATIVOS  PASSIVOS / ATIVOS
# ...

# %%
acoes[' LIQUIDEZ MEDIA DIARIA'].to_string()
# Out:
# '540    1.853846e+09\n408    1.755434e+09\n304    7.620337e+08\n45     7.344795e+08\n43     5.721815e+08\n           ...     \n75     0.000000e+00\n518    0.000000e+00\n151    0.000000e+00\n331    0.000000e+00\n368    0.000000e+00\nName:  LIQUIDEZ MEDIA DIARIA, Length: 563, dtype: float64'

# %%
acoes.loc[acoes['P/L'] > 0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 421 entries, 540 to 368
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   TICKER                  421 non-null    object
#  1   PRECO                   421 non-null    float64
#  2   DY                      421 non-null    float64
#  3   P/L                     421 non-null    float64
#  4   P/VP                    421 non-null    float64
#  5   P/ATIVOS                421 non-null    float64
#  6   MARGEM BRUTA            421 non-null    float64
#  7   MARGEM EBIT             421 non-null    float64
#  8   MARG. LIQUIDA           421 non-null    float64
#  9   P/EBIT                  421 non-null    float64
#  10  EV/EBIT                 421 non-null    float64
#  11  DIVIDA LIQUIDA / EBIT   421 non-null    float64
#  12  DIV. LIQ. / PATRI.      421 non-null    float64
#  13  PSR                     421 non-null    float64
# ...
